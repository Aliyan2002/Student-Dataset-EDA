# %% [markdown]
# # EDA on Students Info

# %%
# Loading the required libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv("student_data.csv")
df.head(5)
# Out:
#   school sex  age address famsize Pstatus  Medu  Fedu     Mjob      Fjob  ...  \
# 0     GP   F   18       U     GT3       A     4     4  at_home   teacher  ...
# 1     GP   F   17       U     GT3       T     1     1  at_home     other  ...
# 2     GP   F   15       U     LE3       T     1     1  at_home     other  ...
# 3     GP   F   15       U     GT3       T     4     2   health  services  ...
# 4     GP   F   16       U     GT3       T     3     3    other     other  ...
#
#   famrel freetime  goout  Dalc  Walc health absences  G1  G2  G3
# 0      4        3      4     1     1      3        6   5   6   6
# 1      5        3      3     1     1      3        4   5   5   6
# 2      4        3      2     2     3      3       10   7   8  10
# 3      3        2      2     1     1      5        2  15  14  15
# 4      4        3      2     1     2      5        4   6  10  10
#
# [5 rows x 33 columns]

# %% [markdown]
# # Univariate EDA

# %% [markdown]
# # For Numerical Features

# %%
# Getting the dataset description
df.describe()
# Out:
#               age        Medu        Fedu  traveltime   studytime    failures  \
# count  395.000000  395.000000  395.000000  395.000000  395.000000  395.000000
# mean    16.696203    2.749367    2.521519    1.448101    2.035443    0.334177
# std      1.276043    1.094735    1.088201    0.697505    0.839240    0.743651
# min     15.000000    0.000000    0.000000    1.000000    1.000000    0.000000
# 25%     16.000000    2.000000    2.000000    1.000000    1.000000    0.000000
# 50%     17.000000    3.000000    2.000000    1.000000    2.000000    0.000000
# 75%     18.000000    4.000000    3.000000    2.000000    2.000000    0.000000
# max     22.000000    4.000000    4.000000    4.000000    4.000000    3.000000
#
#            famrel    freetime       goout        Dalc        Walc      health  \
# count  395.000000  395.000000  395.000000  395.000000  395.000000  395.000000
# mean     3.944304    3.235443    3.108861    1.481013    2.291139    3.554430
# ...

# %% [markdown]
# # Description of age
# 1. Mean Age is 16.696 units.
# 2. Minimum Age is 15 units.
# 3. Median Age is 17 units.
# 4. Maximum Age is 22 units.

# %% [markdown]
# # Description of Medu
# 1. Mean Medu is 2.749 units.
# 2. Minimum Medu is 0 units.
# 3. Median Medu is 3 units.
# 4. Maximum Medu is 4 units.

# %% [markdown]
# # Description of Fedu
# 1. Mean Fedu is 2.521 units.
# 2. Minimum Fedu is 0 units.
# 3. Median Fedu is 2 units.
# 4. Maximum Fedu is 4 units.

# %% [markdown]
# # Description of traveltime
# 1. Mean traveltime is 1.448 units.
# 2. Minimum traveltime is 1 units.
# 3. Median traveltime is 1 units.
# 4. Maximum traveltime is 4 units.

# %% [markdown]
# # Description of studytime
# 1. Mean studytime is 2.035 units.
# 2. Minimum studytime is 1 units.
# 3. Median studytime is 2 units.
# 4. Maximum studytime is 4 units.

# %% [markdown]
# # Description of failures
# 1. Mean failures is 0.334 units.
# 2. Minimum failures is 0 units.
# 3. Median failures is 0 units.
# 4. Maximum failures is 3 units.

# %% [markdown]
# # Description of famrel
# 1. Mean famrel is 3.944 units.
# 2. Minimum famrel is 1 units.
# 3. Median famrel is 4 units.
# 4. Maximum famrel is 5 units.

# %% [markdown]
# # Description of freetime
# 1. Mean freetime is 3.235 units.
# 2. Minimum freetime is 1 units.
# 3. Median freetime is 3 units.
# 4. Maximum freetime is 5 units.

# %% [markdown]
# # Description of go-out
# 1. Mean goout is 3.108 units.
# 2. Minimum goout is 1 units.
# 3. Median goout is 3 units.
# 4. Maximum goout is 5 units.

# %% [markdown]
# # Description of Dalc
# 1. Mean Dalc is 1.481 units.
# 2. Minimum Dalc is 1 units.
# 3. Median Dalc is 1 units.
# 4. Maximum Dalc is 5 units.

# %% [markdown]
# # Description of Walc
# 1. Mean Walc is 2.291 units.
# 2. Minimum Walc is 1 units.
# 3. Median Walc is 2 units.
# 4. Maximum Walc is 5 units.

# %% [markdown]
# # Description of health
# 1. Mean health is 3.554 units.
# 2. Minimum health is 1 units.
# 3. Median health is 4 units.
# 4. Maximum health is 5 units.

# %% [markdown]
# # Description of absences
# 1. Mean absences is 5.708 units.
# 2. Minimum absences is 0 units.
# 3. Median absences is 4 units.
# 4. Maximum absences is 75 units.

# %% [markdown]
# # Description of G1
# 1. Mean G1 is 10.908 units.
# 2. Minimum G1 is 3 units.
# 3. Median G1 is 11 units.
# 4. Maximum G1 is 19 units.

# %% [markdown]
# # Description of G2
# 1. Mean G2 is 10.713 units.
# 2. Minimum G2 is 0 units.
# 3. Median G2 is 11 units.
# 4. Maximum G2 is 19 units.

# %% [markdown]
# # Description of G3
# 1. Mean G3 is 10.415 units.
# 2. Minimum G3 is 0 units.
# 3. Median G3 is 11 units.
# 4. Maximum G3 is 20 units.

# %% [markdown]
# # Boxplot of Age

# %%
import seaborn as sns
sns.boxplot(x="age",data=df)
# Out:
# <AxesSubplot:xlabel='age'>

# %% [markdown]
# # Boxplot of Medu

# %%
sns.boxplot(x="Medu",data=df)
# Out:
# <AxesSubplot:xlabel='Medu'>

# %% [markdown]
# # Boxplot of Fedu

# %%
import seaborn as sns
sns.boxplot(x="Fedu",data=df)
# Out:
# <AxesSubplot:xlabel='Fedu'>

# %% [markdown]
# # Boxplot of traveltime

# %%
import seaborn as sns
sns.boxplot(x="traveltime",data=df)
# Out:
# <AxesSubplot:xlabel='traveltime'>

# %% [markdown]
# # Boxplot of studytime

# %%
import seaborn as sns
sns.boxplot(x="studytime",data=df)
# Out:
# <AxesSubplot:xlabel='studytime'>

# %% [markdown]
# # Boxplot of failures

# %%
import seaborn as sns
sns.boxplot(x="failures",data=df)
# Out:
# <AxesSubplot:xlabel='failures'>

# %% [markdown]
# # Boxplot of famrel

# %%
import seaborn as sns
sns.boxplot(x="famrel",data=df)
# Out:
# <AxesSubplot:xlabel='famrel'>

# %% [markdown]
# # Boxplot of freetime

# %%
import seaborn as sns
sns.boxplot(x="freetime",data=df)
# Out:
# <AxesSubplot:xlabel='freetime'>

# %% [markdown]
# # Boxplot of go-out

# %%
import seaborn as sns
sns.boxplot(x="goout",data=df)
# Out:
# <AxesSubplot:xlabel='goout'>

# %% [markdown]
# # Boxplot of Dalc

# %%
import seaborn as sns
sns.boxplot(x="Dalc",data=df)
# Out:
# <AxesSubplot:xlabel='Dalc'>

# %% [markdown]
# # Boxplot of Walc

# %%
import seaborn as sns
sns.boxplot(x="Walc",data=df)
# Out:
# <AxesSubplot:xlabel='Walc'>

# %% [markdown]
# # Boxplot of health

# %%
import seaborn as sns
sns.boxplot(x="health",data=df)
# Out:
# <AxesSubplot:xlabel='health'>

# %% [markdown]
# # Boxplot of absences

# %%
import seaborn as sns
sns.boxplot(x="absences",data=df)
# Out:
# <AxesSubplot:xlabel='absences'>

# %% [markdown]
# # Boxplot of G1

# %%
import seaborn as sns
sns.boxplot(x="G1",data=df)
# Out:
# <AxesSubplot:xlabel='G1'>

# %% [markdown]
# # Boxplot of G2

# %%
import seaborn as sns
sns.boxplot(x="G2",data=df)
# Out:
# <AxesSubplot:xlabel='G2'>

# %% [markdown]
# # Boxplot of G3

# %%
import seaborn as sns
sns.boxplot(x="G3",data=df)
# Out:
# <AxesSubplot:xlabel='G3'>

# %% [markdown]
# # For Categorical

# %%
sns.countplot('sex',data=df)
# Out:
# <AxesSubplot:xlabel='sex', ylabel='count'>

# %%
df['sex'].value_counts()
# Out:
# F    208
# M    187
# Name: sex, dtype: int64

# %%
df['school'].value_counts()
# Out:
# GP    349
# MS     46
# Name: school, dtype: int64

# %%
sns.countplot('age',data=df)
# Out:
# C:\Users\Arshan\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='age', ylabel='count'>

# %% [markdown]
# # Bi-Variate EDA

# %%
# Using correlation matrix to find out the relation between features
cor=df.corr()
sns.heatmap(cor,annot=True)
# Out:
# <AxesSubplot:>

# %%
1. Height is Highly Correlated with Length, Diameter, All Weights.
2. Length is Highly Correlated with Diameter, Height, All Weights.
3. Diameter is Highly Correlated with Length, Height, All Weights.
4. All weights are Highly Correlated with Length, Height, Diameter.
5. Our Target Variables i.e. Rings and Age have higher correlation with Length, Height, Diameter, Shell Weight.

# %%
cor=df.corr()
cor['G3'].abs().sort_values(ascending=False)
# Out:
# G3            1.000000
# G2            0.904868
# G1            0.801468
# failures      0.360415
# Medu          0.217147
# age           0.161579
# Fedu          0.152457
# goout         0.132791
# traveltime    0.117142
# studytime     0.097820
# health        0.061335
# Dalc          0.054660
# Walc          0.051939
# famrel        0.051363
# absences      0.034247
# freetime      0.011307
# Name: G3, dtype: float64

# %% [markdown]
# # Medu Vs Fedu

# %%
sns.scatterplot('Medu','Fedu',data=df)
# Out:
# C:\Users\Arshan\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Medu', ylabel='Fedu'>

# %% [markdown]
# # Traveltime Vs Medu

# %%
sns.scatterplot('traveltime','Medu',data=df)
# Out:
# C:\Users\Arshan\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='traveltime', ylabel='Medu'>

# %% [markdown]
# # studytime vs Walc

# %%
sns.scatterplot('studytime','Walc',data=df)
# Out:
# C:\Users\Arshan\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='studytime', ylabel='Walc'>

# %% [markdown]
# # Failures Vs G3

# %%
sns.scatterplot('failures', 'G3',data=df)
# Out:
# C:\Users\Arshan\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='failures', ylabel='G3'>

# %% [markdown]
# # famrel Vs Freetime

# %%
sns.scatterplot('famrel','freetime',data=df)
# Out:
# C:\Users\Arshan\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='famrel', ylabel='freetime'>

# %% [markdown]
# # Freetime Vs Go-Out

# %%
sns.scatterplot('freetime','goout',data=df)
# Out:
# C:\Users\Arshan\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='freetime', ylabel='goout'>

# %% [markdown]
# # Go-Out Vs Walc

# %%
sns.scatterplot('goout','Walc',data=df)
# Out:
# C:\Users\Arshan\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='goout', ylabel='Walc'>

# %% [markdown]
# # Health Vs G2

# %%
sns.scatterplot('health','G2',data=df)
# Out:
# C:\Users\Arshan\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='health', ylabel='G2'>

# %% [markdown]
# # Absences Vs Age

# %%
sns.scatterplot('absences','age',data=df)
# Out:
# C:\Users\Arshan\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='absences', ylabel='age'>

# %% [markdown]
# # G1 Vs G2

# %%
sns.scatterplot('G1','G2',data=df)
# Out:
# C:\Users\Arshan\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='G1', ylabel='G2'>

# %% [markdown]
# # G2 Vs G3

# %%
sns.scatterplot('G2','G3',data=df)
# Out:
# C:\Users\Arshan\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='G2', ylabel='G3'>

# %%
Multivariate EDA

# %%
Pairplots with respect to gender

# %%
sns.pairplot(data=df,hue="sex")
